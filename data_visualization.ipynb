# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import os

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Administrador\\OneDrive - UNIVERSIDAD NACIONAL DE INGENIERIA\\Desktop\\Personal\\Statistics - Data Science\\Statistics\\statistics_for_good'

# %%
df=pd.read_csv("data/diastolic_bp_study.csv")

# %%
df.head()
# Out:
#    Subject_Number Gender  Age  Dosage_Tablets  Diastolic_BP_Start  \
# 0            1001      M   45               2               100.2
# 1            1002      M   41               1                98.5
# 2            1003      F   51               2               100.8
# 3            1004      F   46               2               101.1
# 4            1005      F   47               3               100.0
#
#    Diastolic_BP_End
# 0             100.1
# 1             100.0
# 2             101.1
# 3             100.9
# 4              99.8

# %%
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Subject_Number      20 non-null     int64
#  1   Gender              20 non-null     object
#  2   Age                 20 non-null     int64
#  3   Dosage_Tablets      20 non-null     int64
#  4   Diastolic_BP_Start  20 non-null     float64
#  5   Diastolic_BP_End    20 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.1+ KB

# %% [markdown]
# ## Plots for categorical variables

# %% [markdown]
# ### Pie chart

# %%
labels=df["Gender"].value_counts().index
sizes=df["Gender"].value_counts().values
plt.pie(sizes,
        labels=labels,
        explode=(.1,0), # separe from center
        colors=["#6673D4","#F5CF27"],
        autopct="%1.1f%%",
        pctdistance=.6,
        shadow=True,
        startangle=90,
        radius=1.2,
        counterclock=False,
        wedgeprops={"linewidth":3},
        textprops={'fontsize':12,'color':'black','fontweight':'normal',
                   'family':'Candara'},
        center=(0,0),
        frame=False,
        normalize=True)
plt.title("Gender distribution",
          fontsize=14,
          fontweight="normal", # bold
          fontfamily="Candara",
          pad=20);

# %% [markdown]
# ### Bar plot

# %%
categories=df["Gender"].value_counts().index
values=df["Gender"].value_counts().values
xticks_dict={"M":"Masculine","F":"Feminine"}
labels=[xticks_dict[i] for i in categories]

# %%
plt.bar(categories,values,
        color=["#6673D4","#F5CF27"],
        edgecolor="#0F1C57",
        width=.8) # width and separation between bars
plt.xlabel("Gender",fontfamily="Candara",fontsize=12)
plt.ylabel("Count",fontfamily="Candara",fontsize=12)
plt.xticks(range(len(values)),labels,fontfamily="Candara",fontsize=12)
plt.yticks(fontfamily="Candara",fontsize=12)
plt.title("Gender distribution",
          fontsize=14,
          fontweight="normal",
          fontfamily="Candara",
          pad=20);
